# %%
import os
import pandas as pd

base_dir = os.getcwd()
path = os.path.join(base_dir, '..', '..', 'Storage', 'Database', 'database.parquet')
path = os.path.abspath(path)

df = pd.read_parquet(path)

# %%
df.head(10)
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2025-01-01 00:18:38   2025-01-01 00:26:59              1.0
# 1         1  2025-01-01 00:32:40   2025-01-01 00:35:13              1.0
# 2         1  2025-01-01 00:44:04   2025-01-01 00:46:01              1.0
# 3         2  2025-01-01 00:14:27   2025-01-01 00:20:01              3.0
# 4         2  2025-01-01 00:21:34   2025-01-01 00:25:06              3.0
# 5         2  2025-01-01 00:48:24   2025-01-01 01:08:26              2.0
# 6         1  2025-01-01 00:14:47   2025-01-01 00:16:15              0.0
# 7         1  2025-01-01 00:39:27   2025-01-01 00:51:51              0.0
# 8         1  2025-01-01 00:53:43   2025-01-01 01:13:23              0.0
# 9         2  2025-01-01 00:00:02   2025-01-01 00:09:36              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           1.60         1.0                  N           229           237
# ...

# %%
df.shape[0]
# Out:
# 3475226

# %%
df[['VendorID']].drop_duplicates().head(15)
# Out:
#          VendorID
# 0               1
# 3               2
# 31891           7
# 2943550         6

# %%
df[['RatecodeID']].drop_duplicates().head(20)
#Obs na dim tirar NaN trocar pra 99 = Null/unknown  (unknown=desconhecido)
# Out:
#          RatecodeID
# 0               1.0
# 98              5.0
# 279            99.0
# 312             2.0
# 767             4.0
# 902             3.0
# 112362          6.0
# 2935077         NaN

# %%
df[['payment_type']].drop_duplicates().head(20)
# Out:
#          payment_type
# 0                   1
# 3                   2
# 22                  4
# 445                 3
# 393338              5
# 2935077             0

# %%
df[['store_and_fwd_flag']].drop_duplicates().head(20) 
#  tirar NaN,None  ou '' da base dim geração   trocar pra  u ou UNK padrao com coluna RatecodeID Null/unknown  --(unknown=desconhecido)
# Out:
#         store_and_fwd_flag
# 0                        N
# 92                       Y
# 2935077               None

# %%
df[['PULocationID']].drop_duplicates().head(20) # tentar achar o arquivo com localização (Plus para contratação)
# Out:
#     PULocationID
# 0            229
# 1            236
# 2            141
# 3            244
# 5            239
# 6            170
# 7            234
# 8            148
# 9            237
# 11           263
# 15           158
# 16           164
# 17            79
# 19           246
# 22           137
# 24           142
# 26           143
# 27           113
# 28            90
# 29           140

# %%
df[['DOLocationID']].drop_duplicates().head(20)
# Out:
#     DOLocationID
# 0            237
# 2            141
# 3            244
# 4            116
# 5             68
# 6            170
# 7            148
# 9            262
# 10            75
# 11           236
# 12           151
# 14           113
# 16           229
# 17           107
# 19            90
# 22           233
# 25           239
# 26           143
# 28           246
# 29           263

# %%
print(df['tpep_pickup_datetime'].min())
print(df['tpep_pickup_datetime'].max())
# Out:
# 2024-12-31 20:47:55
# 2025-02-01 00:00:44

# %% [markdown]
# Base Extra CSV
# https://www.nyc.gov/site/tlc/about/tlc-trip-record-data.page

# %%
#Teste Criar Dimensoes
'''
FatoCorrida = Todas datas,ids e métricas
Dimensões:
DimVendor (Dimensão do fornecedor do táxi)
DimRatecode (Tipo de tarifa)
DimLocation (Localização - para pickup e dropoff) -- Plus contratação , tentar achar arquivo com ID das localizações 
DimPayment (Forma de pagamento)
DimCalendário 
'''
# Out:
# '\nFatoCorrida = Todas datas,ids e métricas\nDimensões:\nDimVendor (Dimensão do fornecedor do táxi)\nDimRatecode (Tipo de tarifa)\nDimLocation (Localização - para pickup e dropoff) -- Plus contratação , tentar achar arquivo com ID das localizações \nDimPayment (Forma de pagamento)\nDimCalendário \n'

# %% [markdown]
# DimVendor

# %%
#DimVendor
df[['VendorID']].drop_duplicates().head(15)
# Out:
#          VendorID
# 0               1
# 3               2
# 31891           7
# 2943550         6

# %%
import os
from path_origem_parquet import get_parquet_path

path_parquet = os.path.join(get_parquet_path(), 'database.parquet')
#print(path_parquet)
df_vendor = pd.read_parquet(path_parquet)

# %%
#df_vendor.head(2)
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2025-01-01 00:18:38   2025-01-01 00:26:59              1.0
# 1         1  2025-01-01 00:32:40   2025-01-01 00:35:13              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            1.6         1.0                  N           229           237
# 1            0.5         1.0                  N           236           237
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0             1         10.0    3.5      0.5        3.00           0.0
# 1             1          5.1    3.5      0.5        2.02           0.0
#
#    improvement_surcharge  total_amount  congestion_surcharge  Airport_fee  \
# 0                    1.0         18.00                   2.5          0.0
# 1                    1.0         12.12                   2.5          0.0
#
#    cbd_congestion_fee
# 0                 0.0
# 1                 0.0

# %%
df_dim_vendor = df[['VendorID']].drop_duplicates().head(15).copy()


map_vendor = {
    1: 'Creative Mobile Technologies, LLC',
    2: 'Curb Mobility, LLC',
    6: 'Myle Technologies Inc',
    7: 'Helix'
}

df_dim_vendor['VendorName'] = df_dim_vendor['VendorID'].map(map_vendor)

# Exibir resultado
df_dim_vendor.head()
# Out:
#          VendorID                         VendorName
# 0               1  Creative Mobile Technologies, LLC
# 3               2                 Curb Mobility, LLC
# 31891           7                              Helix
# 2943550         6              Myle Technologies Inc

# %%
destination_vendor = os.path.join(base_dir, '..', '..', 'Storage', 'Dim', 'dim_vendor.parquet')
df_dim_vendor.to_parquet(destination_vendor, index=False)

# %%
# ler de teste
df_test_vendor = pd.read_parquet(destination_vendor)
df_test_vendor.head()
# Out:
#    VendorID                         VendorName
# 0         1  Creative Mobile Technologies, LLC
# 1         2                 Curb Mobility, LLC
# 2         7                              Helix
# 3         6              Myle Technologies Inc

# %%
map_vendor = {
    1: 'Creative Mobile Technologies, LLC',
    2: 'Curb Mobility, LLC',
    6: 'Myle Technologies Inc',
    7: 'Helix'
}

df['VendorName'] = df['VendorID'].map(map_vendor)

# %% [markdown]
# DimRatecode

# %%
import os
import pandas as pd
from path_origem_parquet import get_parquet_path
from path_destination_Dim import get_dim_path

path_parquet = os.path.join(get_parquet_path(), 'database.parquet')
destination_Ratecode = os.path.join(get_dim_path(), 'dim_vendor_jan.parquet')

# %%
# Obs: d calendário pode ser criado direto em consulta SQL,view ou direto no power bi Depende de cada projeto 
import pandas as pd
import locale

locale.setlocale(locale.LC_TIME, 'Portuguese_Brazil.1252')  # Dia_da_Semana em portugues

datas = pd.date_range(start='2020-01-01', end='2030-12-31', freq='D')
df_calendario = pd.DataFrame({'Data': datas})

df_calendario['Ano'] = df_calendario['Data'].dt.year
df_calendario['Mes'] = df_calendario['Data'].dt.month
df_calendario['Dia'] = df_calendario['Data'].dt.day
df_calendario['Dia_da_Semana'] = df_calendario['Data'].dt.strftime('%A')
df_calendario['Trimestre'] = df_calendario['Data'].dt.quarter
df_calendario['Mes_Abreviado'] = df_calendario['Data'].dt.strftime('%b')
df_calendario.head(5)
# Out:
#         Data   Ano  Mes  Dia Dia_da_Semana  Trimestre Mes_Abreviado
# 0 2020-01-01  2020    1    1  quarta-feira          1           jan
# 1 2020-01-02  2020    1    2  quinta-feira          1           jan
# 2 2020-01-03  2020    1    3   sexta-feira          1           jan
# 3 2020-01-04  2020    1    4        sábado          1           jan
# 4 2020-01-05  2020    1    5       domingo          1           jan
